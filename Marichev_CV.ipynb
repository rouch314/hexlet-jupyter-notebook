# %% [markdown]
# # Маричев Сергей Геннадьевич
#
# Хочу стать крутым аналитиком данных.
#
# *Список контактов*:
#
# * Маричева Наталья Анатольевна;
# * Маричева Людмила Сергеевна;
# * Маричев Геннадий Павлович;
# * Батухтин Антон Александрович.

# %% [markdown]
# **Еще контакты:**
#
# - Github: https://github.com/rouch314
# - Телефон: +7(927)9340980
# - Почта: prophet314@gmail.com
# - Телеграм: @inok_314

# %% [markdown]
# ## <span style="color:blue"> О себе </span>
#
# Почти гик. Люблю компьютерные игры, книги, фильмы и всю поп-культуру. Metalhead (почти).

# %% [markdown]
# ## Навыки
#
# + HTML
# + CSS
# + Python
# + SQL
# + Pandas
# + Numpy
# + Matplotlib
